# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhairyasummi/python/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
path = '/content/drive/MyDrive/dataset/Copy of imdb_data.csv'

# %%
df = pd.read_csv(path)
df.head()             # it will give the first 5 rows by default if no mentioned
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df.tail()     #it will give the last 5 rows by default
# Out:
#         id belongs_to_collection    budget  \
# 2995  2996                   NaN         0
# 2996  2997                   NaN         0
# 2997  2998                   NaN  65000000
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2995                               NaN  tt0109403                en
# 2996                               NaN  tt2364975                sv
# 2997                               NaN  tt0116908                en
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# ...

# %%
df.info()        #it will give the basic info of the dataaset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
df.iloc[:5,3:5]            #this gets rows(or colums) at particular possition in the index
# Out:
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage
# 0                                NaN
# 1                                NaN
# 2  http://sonyclassics.com/whiplash/
# 3         http://kahaanithefilm.com/
# 4                                NaN

# %%
df.loc[:5,['title','runtime','revenue']]       #this gets rows/columns with particulatr index
# Out:
#                                       title  runtime   revenue
# 0                    Hot Tub Time Machine 2     93.0  12314651
# 1  The Princess Diaries 2: Royal Engagement    113.0  95149435
# 2                                  Whiplash    105.0  13092000
# 3                                   Kahaani    122.0  16000000
# 4                                Marine Boy    118.0   3923970
# 5    Pinocchio and the Emperor of the Night     83.0   3261638

# %%
df[df['original_language'] == 'hi'][['title','runtime','original_language','revenue']]
# Out:
#                                  title  runtime original_language    revenue
# 3                              Kahaani    122.0                hi   16000000
# 213                      Rowdy Rathore    143.0                hi   31000000
# 371                          Thank You    140.0                hi    4100000
# 401         The Legend of Bhagat Singh    155.0                hi    6000000
# 419   Dear Guest, When Will You Leave?    155.0                hi    5000000
# 481             Chandni Chowk To China    149.0                hi    9400000
# 585                             Dangal    161.0                hi  310000000
# 627                                Fan    142.0                hi   29251596
# 671                    Anjaana Anjaani    151.0                hi    5900000
# 695                          Tere Naam    132.0                hi          2
# 771                            Kaminey    135.0                hi   18130000
# ...

# %%
df[df['runtime'] == 338][['title','runtime','original_language','revenue']]
# Out:
#        title  runtime original_language  revenue
# 1211  Carlos    338.0                en   871279

# %%
df['half_runtime'] = df['runtime']/2
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df['profit'] = df['revenue']- df['budget']
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
df[df['profit'] == df['profit'].max()]        # shows the max value from the dataset
# Out:
#         id                              belongs_to_collection     budget  \
# 1761  1762  [{'id': 9485, 'name': 'The Fast and the Furiou...  190000000
#
#                               genres                  homepage    imdb_id  \
# 1761  [{'id': 28, 'name': 'Action'}]  http://www.furious7.com/  tt2820852
#
#      original_language original_title  \
# 1761                en      Furious 7
#
#                                                overview  popularity  ...  \
# 1761  Deckard Shaw seeks revenge against Dominic Tor...   27.275687  ...
#
#         status              tagline      title  \
# 1761  Released  Vengeance Hits Home  Furious 7
#
#                                                Keywords  \
# 1761  [{'id': 830, 'name': 'car race'}, {'id': 3428,...
#
#                                                    cast  \
# 1761  [{'cast_id': 17, 'character': 'Dominic Toretto...
#
#                                                    crew     revenue  \
# ...

# %%
df[df['profit'] == df['profit'].min()]     # shows the min value from the dataset
# Out:
#         id belongs_to_collection     budget  \
# 2623  2624                   NaN  197471676
#
#                                                  genres homepage    imdb_id  \
# 2623  [{'id': 12, 'name': 'Adventure'}, {'id': 878, ...      NaN  tt2239822
#
#      original_language                               original_title  \
# 2623                en  Valerian and the City of a Thousand Planets
#
#                                                overview  popularity  ...  \
# 2623  In the 28th century, Valerian and Laureline ar...   15.262706  ...
#
#         status tagline                                        title  \
# 2623  Released     NaN  Valerian and the City of a Thousand Planets
#
#                                                Keywords  cast crew   revenue  \
# 2623  [{'id': 1370, 'name': 'shapeshifting'}, {'id':...   NaN  NaN  90024292
#
#      half_runtime     profit  max_profit
# 2623         68.5 -107447384  1316249360
#
# [1 rows x 26 columns]

# %%
df.columns  #shows the columns in the dataaset
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue',
#        'half_runtime', 'profit', 'max_profit'],
#       dtype='object')

# %%
df.drop(['runtime'], axis=1, inplace=True) # deletes the valeu from the dataset permanently

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'spoken_languages', 'status',
#        'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue', 'profit',
#        'max_profit'],
#       dtype='object')

# %%
df.sort_values('revenue', ascending=False)[['title', 'revenue']]
# Out:
#                                title     revenue
# 1126                    The Avengers  1519557910
# 1761                       Furious 7  1506249360
# 2770         Avengers: Age of Ultron  1405403694
# 684             Beauty and the Beast  1262886337
# 2322  Transformers: Dark of the Moon  1123746996
# ...                              ...         ...
# 695                        Tere Naam           2
# 1917                 The Merry Widow           1
# 347          The Wind in the Willows           1
# 1754                    Mute Witness           1
# 1874                         Missing           1
#
# [3000 rows x 2 columns]

# %%
df['profit'].mean()
# Out:
# np.float64(44194517.77866667)

# %%
df['profit'].median()
# Out:
# 6121122.5

# %%
df['profit'].mode()
# Out:
# 0    0
# Name: profit, dtype: int64

# %%
df['release_Date'] = pd.to_datetime(df['release_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 25 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %%
df['release_date'][0]
# Out:
# '2/20/15'

# %%
df['original_language'].unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
df['original_language'].nunique()
# Out:
# 36

# %%
df['original_language'].value_counts()
# Out:
# original_language
# en    2575
# fr      78
# ru      47
# es      43
# hi      42
# ja      37
# it      24
# ko      20
# cn      20
# zh      19
# de      18
# ta      16
# sv       8
# pt       6
# nl       6
# fa       5
# da       5
# ro       4
# hu       3
# tr       3
# no       2
# te       2
# pl       2
# fi       2
# ml       2
# sr       1
# cs       1
# mr       1
# ar       1
# he       1
# ur       1
# el       1
# vi       1
# nb       1
# bn       1
# id       1
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# profit                      0
# max_profit                  0
# release_Date                0
# dtype: int64

# %%
df['belongs_to_collection'].fillna('not present', inplace=True)
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                        not present   3300000
# 3   4                                        not present   1200000
# 4   5                                        not present         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %%
# tilt function
